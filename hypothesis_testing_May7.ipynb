# %% [markdown]
# For each of the following questions, formulate a null and alternative hypothesis (be as specific as you can be), then give an example of what a true positive, true negative, type I and type II errors would look like. Note that some of the questions are intentionally phrased in a vague way. It is your job to reword these as more precise questions that could be tested.
#
# - Has the network latency gone up since we switched internet service providers?
# - Is the website redesign any good?
# - Is our television ad driving more sales?

# %% [markdown]
# #### #1. Has the network latency gone up since we switched internet service providers?
# - $H_{0}$: there is no change to network latency since switching providers
# - $H_{a}$: there is a change in network latency since switching providers
# - True Positive: I reject the $H_{0}$, and the network latency has chanced since switching providers
# - True Negative: I fail to reject the $H_{0}$, and the network latency has not chanced since switching providers
# - Type I error: I reject the $H_{0}$, but switching provides does not change network latency
# - Type II error: I fail to reject the $H_{0}$, but switching provides does change network latency

# %% [markdown]
# #### #2. Is the website redesign any good?
# - $H_{0}$: the website redesign has caused no change in revenue
# - $H_{a}$: the website redesign has caused revenue to increase significantly
# - True Positive: I reject the $H_{0}$, and the web redesign does change revenue
# - True Negative: I fail to reject the $H_{0}$, and web redesign do not change revenue
# - Type I error: I reject the $H_{0}$,but web redesign do not change revenue
# - Type II error: I fail to reject the $H_{0}$, but web redesign do change revenue

# %% [markdown]
# #### #3. Is our television ad driving more sales?
# - $H_{0}$: the television ad is not driving more sales
# - $H_{a}$: the television ad does drive more sales
# - True Positive: I reject the $H_{0}$, and the television ads do drive sales
# - True Negative: I fail to reject the $H_{0}$, and television ads do not drive more sales
# - Type I error: I reject the $H_{0}$,but television ads do not drive sales
# - Type II error: I fail to reject the $H_{0}$, but television ads do drive sales

# %% [markdown]
# ### EXTRA PRACTICE

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pydataset import data
import seaborn as sns
from env import host, user, password

# %%
url = f'mysql+pymysql://{user}:{password}@{host}/zillow'

# %%
def get_db_url(user, password, host, db_name):
    return f'mysql+pymysql://{user}:{password}@{host}/{db_name}'

# %% [markdown]
# ### Does room count increase tax value?

# %% [markdown]
# - USE zillow;
#
# - select taxvaluedollarcnt, roomcnt
# - from properties_2017;

# %%
value_roomcnt_hypothesis = pd.read_sql('SELECT taxvaluedollarcnt, roomcnt FROM properties_2017 order by roomcnt desc limit 100', url)
value_roomcnt_hypothesis
# Out:
#     taxvaluedollarcnt  roomcnt
# 0           1107323.0     96.0
# 1            349613.0     86.0
# 2            817728.0     84.0
# 3            385032.0     77.0
# 4            402312.0     67.0
# 5            454548.0     56.0
# 6            374376.0     52.0
# 7            321014.0     45.0
# 8            173090.0     42.0
# 9            307040.0     40.0
# 10           311849.0     31.0
# 11           414684.0     30.0
# 12           414684.0     30.0
# 13           414684.0     30.0
# 14           414684.0     30.0
# 15           414684.0     30.0
# 16           414684.0     30.0
# 17           414684.0     30.0
# 18           414684.0     30.0
# 19           414684.0     30.0
# 20           414684.0     30.0
# 21           414684.0     30.0
# 22           414684.0     30.0
# 23           414684.0     30.0
# 24           414684.0     30.0
# 25           211073.0     24.0
# 26          5310449.0     22.0
# 27          2362076.0     21.0
# 28         26879210.0     21.0
# ...

# %% [markdown]
# - $H_{0}$: room count does not increase tax
# - $H_{a}$: room count does increase tax
# - True Positive: I reject the $H_{0}$, and room count does increase tax value
# - True Negative: I fail to reject the $H_{0}$, and room count does not increase tax value
# - Type I error: I reject the $H_{0}$,but room count does not increase tax value
# - Type II error: I fail to reject the $H_{0}$, but room count does increase tax value

# %% [markdown]
# ### Does finished square feet increase bath room count?

# %% [markdown]
# - Use Zillow;
# - SELECT bathroomcnt, calculatedfinishedsquarefeet
# - FROM properties_2017
# - ORDER BY calculatedfinishedsquarefeet DESC
# - limit 25

# %%
sqft_bthcnt_hypothesis = pd.read_sql('SELECT bathroomcnt, calculatedfinishedsquarefeet FROM properties_2017 order by bathroomcnt desc limit 25', url)
sqft_bthcnt_hypothesis
# Out:
#     bathroomcnt  calculatedfinishedsquarefeet
# 0          32.0                       39170.0
# 1          31.0                       14680.0
# 2          20.0                       16198.0
# 3          20.0                        1650.0
# 4          20.0                       11382.0
# 5          20.0                       28725.0
# 6          20.0                          66.0
# 7          20.0                       11700.0
# 8          20.0                        9877.0
# 9          20.0                          80.0
# 10         19.5                       26345.0
# 11         19.0                       11439.0
# 12         19.0                       31415.0
# 13         19.0                        1367.0
# 14         18.0                          56.0
# 15         18.0                       18056.0
# 16         18.0                        6040.0
# 17         18.0                       11134.0
# 18         18.0                       18654.0
# ...

# %% [markdown]
# - $H_{0}$: finished square feet does not increase bathroom count
# - $H_{a}$: finished square feet does increase bathroom count
# - True Positive: I reject the $H_{0}$, and finished square feet does increase bathroom count
# - True Negative: I fail to reject the $H_{0}$, and finished square feet does not increase bathroom count
# - Type I error: I reject the $H_{0}$,but finished square feet does not increase increase bathroom count
# - Type II error: I reject the $H_{0}$, but finished square feet does increase bathroom count
